# %% [markdown]
# # Web Scraping
# ![image.png](attachment:image.png)
# Image source: https://www.crawlnow.com/blog/what-is-web-scraping
#
# #### Lab adapted from https://colab.research.google.com/github/dlsun/pods/blob/master/11-Hierarchical-Data/11.3%20Web%20Scraping.ipynb#scrollTo=hMmOJP-ZuWvj
#
# **HTML**, which stands for "hypertext markup language", is an XML-like language for specifying the appearance of web pages. Each tag in HTML corresponds to a specific page element. For example:
#
# - `<img>` specifies an image. The path to the image file is specified in the `src=` attribute.
# - `<a>` specifies a hyperlink. The text enclosed between `<a>` and `</a>` is the text of the link that appears, while the URL is specified in the `href=` attribute of the tag.
# - `<table>` specifies a table. The rows of the table are specified by `<tr>` tags nested inside the `<table>` tag, while the cells in each row are specified by `<td>` tags nested inside each `<tr>` tag.

# %% [markdown]
# # Inspecting HTML Source Code
#
# Suppose we want to scrape faculty information from the [Cal Poly Statistics Department directory](https://statistics.calpoly.edu/content/directory) (`https://statistics.calpoly.edu/content/directory`). Once we have identified a web page that we want to scrape, the next step is to study the HTML source code. All web browsers have a feature that will display the HTML source of a web page.
#
# Visit the web page above, and view the HTML source of that page (Right click, then choose "View Page Source"). Scroll down until you find the HTML code for the table containing information about the name, office, phone, e-mail, and office hours of the faculty members.
#
# Notice how difficult it can be to find a page element in the HTML source. Many browsers allow you to right-click on a page element and jump to the part of the HTML source corresponding to that element. Alternatively, you could pick a string in the desired table and do a Control-F to find that string in the HTML source.

# %% [markdown]
# # Web Scraping Using BeautifulSoup
#
# `BeautifulSoup` is a Python library that makes it easy to navigate an HTML document. We can query tags by name or attribute, and we can narrow our search to the ancestors and descendants of specific tags. Many web sites have malformed HTML. `BeautifulSoup` handles malformed HTML more gracefully than prior scraping packages and is thus the library of choice.
#
# First, we will issue an HTTP request to the URL to get the HTML source code. A response code of 200 means it was successful in getting the source code. A full list of codes is here: https://en.wikipedia.org/wiki/List_of_HTTP_status_codes

# %%
import requests
response = requests.get("https://statistics.calpoly.edu/content/directory")
response
# Out:
# <Response [200]>

# %% [markdown]
# The HTML source is stored in the `.content` attribute of the response object. We pass this HTML source into `BeautifulSoup` to obtain a tree-like representation of the HTML document.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# Now we can search for tags within this HTML document, using tags like `.find_all()`. For example, we can find all tables on this page.

# %%
tables = soup.find_all("table")
len(tables)
# Out:
# 3

# %% [markdown]
# It shows that there are 3 tables on the page. We are interested in the second one, which is index one.

# %%
table = tables[1]
table
# Out:
# <table cellspacing="0" class="directory backwhite" height="2667" summary="COSAM Dean's Office Staff" width="596"><tbody><tr><th scope="col" width="18%">
# <p>Name</p>
# </th>
# <th scope="col" width="8%">Office</th>
# <th scope="col" width="10%">Phone (805)</th>
# <th scope="col" width="20%">Email</th>
# <th scope="col" width="20%">
# <p>Office HoURS </p>
# </th>
# </tr><tr><td><strong>Lubaba Alim</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-111</a></td>
# <td>756-2792</td>
# <td><a href="mailto:lfalim@calpoly.edu">lfalim@calpoly.edu</a></td>
# <td><strong>MWF</strong> 10:10-11am</td>
# </tr><tr><td><a href="/Kelly-Bodwin"><strong>Kelly Bodwin</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25
calpoly.edu</a></td>
# <td>
# <p><strong>MW</strong> 1:10-2:30pm</p>
# <p><strong>R</strong> 1:10-2pm</p>
# </td>
# </tr><tr><td><strong><a href="/Kevin-Ross">Kevin Ross</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-237</a></td>
# <td>756-5739</td>
# <td><a href="mailto:kjross@calpoly.edu">kjross@calpoly.edu</a></td>
# <td>
# <p><strong>M</strong> 10:10-11am</p>
# <p><strong>T</strong> 2:10-3pm</p>
# <p><strong>W</strong> 1:30-2:30pm</p>
# <p><strong>R</strong> 9:30-10:30am</p>
# </td>
# </tr><tr><td>
# <p><strong><a href="/Soma-Roy">Soma Roy</a></strong></p>
# <p>Languages spoken: English, हिन्दी, বাংলা</p>
# </td>
# <td><a href="https://maps.calpoly.edu/">25-104</a></td>
# <td>
# <p>756-5250</p>
# </td>
# <td><a href="mailto:soroy@calpoly.edu">soroy@calpoly.edu</a></td>
# <td>
# <p><strong>W</strong> 10:10-11am; in person</p>
# <p><strong>F</strong> 11:10-12pm; Zoom</p>
# </td>
# </tr><tr><td>
# <p><a href="https://statistics.calpoly.edu/trevor-ruiz"><strong>Trevor Ruiz</strong></a></p>
# <p>Se habla español</p>
# </td>
# <td><a href="https://maps.calpoly.edu/">25-236</a></td>
# <td>756-2776</td>
# <td><a href="mailto:truiz01@calpoly.edu">truiz01@calpoly.edu</a></td>
# <td>
# <p><strong>T-R</strong> 12-2pm</p>
# <p><a href="http://calendly.com/tdruiz/office-hour">Calendly</a></p>
# </td>
# </tr><tr><td>
# <p><strong><a href="/Anelise-Sabbag">Anelise Sabbag</a></strong></p>
# <p>Eu falo português!</p>
# </td>
# <td>
# <p><a href="https://maps.calpoly.edu/">25-222</a></p>
# </td>
# <td>756-5562</td>
# <td>
# <p><a href="mailto:asabbag@calpoly.edu">asabbag@calpoly.edu</a></p>
# </td>
# <td>
# <p><strong>MW </strong>12:10-1pm; in person</p>
# <p><strong>TF</strong> 8:10-9am; Zoom (Link in Canvas)</p>
# </td>
# </tr><tr><td><a href="https://statistics.calpoly.edu/julia-schedler"><strong>Julia Schedler</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-212</a></td>
# <td>756-5877</td>
# <td><a href="mailto:jschedle@calpoly.edu">jschedle@calpoly.edu</a></td>
# <td>
# <p><b>TR </b>3:30-5pm</p>
# </td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/maddie-schroth">Maddie Schroth</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-223</a></td>
# <td>
# <p>756-6310</p>
# </td>
# <td><a href="mailto:mschroth@calpoly.edu">mschroth@calpoly.edu</a></td>
# <td>
# <p><strong>MW</strong> 8:10-9am; <a href="https://calendly.com/mschroth/spring-thursday-office-hours-2025-zoom-clone">Zoom</a></p>
# <p><strong>TR </strong>12:10-1pm; in person</p>
# </td>
# </tr><tr><td><strong>Sonja Schuster</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-119</a></td>
# <td>756-1825</td>
# <td><a href="mailto:sschuste@calpoly.edu">sschuste@calpoly.edu</a></td>
# <td>
# <p><strong>W </strong>4:10-5pm</p>
# <p><strong>R </strong>11:10-12pm<strong> </strong></p>
# <p>only on <a href="https://calpoly.zoom.us/j/2924859737?pwd=VUw3aEwyUlJ4YkMvbUFWbGtZQStZZz09">Zoom</a></p>
# </td>
# </tr><tr><td><strong><a href="/Jeff-Sklar">Jeffrey Skl</a>ar</strong></td>
# <td>
# <p><a href="https://maps.calpoly.edu/">25-110</a></p>
# </td>
# <td>756-6353</td>
# <td><a href="mailto:jsklar@calpoly.edu">jsklar@calpoly.edu</a></td>
# <td>
# <p><strong>MW </strong>1:10-2pm</p>
# <p><strong>TR</strong> 10:10-11am</p>
# </td>
# </tr><tr><td><strong><a href="/Heather-Smith">Heather Smith</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-112</a></td>
# <td>756-6128</td>
# <td><a href="mailto:hsmith@calpoly.edu">hsmith@calpoly.edu</a></td>
# <td>
# <p><strong>TR</strong> 12:15-1pm</p>
# <p><strong>W</strong> 9:15-11am</p>
# <p><a href="https://calendly.com/hsmithcalpoly/student-zoom-15-min-mtg">Calendly</a> &amp; by appointment</p>
# </td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/allison-theobold">Allison Theobold</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-105</a></td>
# <td>756-5529</td>
# <td><a href="mailto:atheobol@calpoly.edu">atheobol@calpoly.edu</a></td>
# <td><strong>MR</strong> 2:10-3pm</td>
# </tr><tr><td><strong><a href="/John-Walker">John Walker</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-226</a></td>
# <td>756-7128</td>
# <td><a href="mailto:jwalker@calpoly.edu">jwalker@calpoly.edu</a></td>
# <td>
# <p>Contact Instructor</p>
# </td>
# </tr><tr><td><strong>Yi-Hui Wang</strong></td>
# <td>25-119</td>
# <td>756-1825</td>
# <td><a href="mailto:ywang59@calpoly.edu">ywang59@calpoly.edu</a></td>
# <td>
# <p><strong>W </strong>10:30-11:30am; in person</p>
# <p><strong>F</strong> 9:10-10am; Zoom</p>
# </td>
# </tr><tr><td><a href="/Immanuel-Williams"><strong>Immanuel Williams</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-113</a></td>
# <td>756-2709</td>
# <td><a href="mailto:imwillia@calpoly.edu">imwillia@calpoly.edu</a></td>
# <td><strong>TR </strong>2-4pm</td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/deniz-yenigun">Deniz Yenigün</a></strong><br/>
# 			Türkçe konuşuyorum</td>
# <td><a href="https://maps.calpoly.edu/">25-129</a></td>
# <td>756-0895</td>
# <td><a href="mailto:dyenigun@calpoly.edu">dyenigun@calpoly.edu</a></td>
# <td>
# <p>N/A</p>
# </td>
# </tr></tbody></table>

# %% [markdown]
# There is one faculty member per row in the table, except for the first row, which is the header. We iterate over all rows except for the first, extracting information about each faculty to append to `rows`, which we will eventually turn into a `DataFrame`. As you read the code below, refer to the HTML source above, so that you understand what each line is doing. In particular, ask yourself the following questions:
#
# - `cells[0]` represents a `<td>` tag. Why do we need to call `.find("strong")` within this tag to get the name of the faculty member?
# - For the most part, `link` is a hyperlink whose text is the faculty's office number. But for some faculty, `link` is `None`. For which faculty is this the case and why?

# %%
rows = []
for faculty in table.find_all("tr")[1:]:
    # Get all the cells in the row.
    cells = faculty.find_all("td")

    # The information we need is the text between tags.
    name_tag = cells[0].find("strong") or cells[0]
    name = name_tag.text

    link = cells[1].find("a")
    office = cells[1].text if link is None else link.text

    email_tag = cells[3].find("a") or cells[3]
    email = email_tag.text

    # Append this data.
    rows.append({
        "name": name,
        "office": office,
        "email": email
    })

# %% [markdown]
# In the code above, observe that `.find_all()` returns a list with all matching tags, while `.find()` returns only the first matching tag. If no matching tags are found, then `.find_all()` will return an empty list `[]`, while `.find()` will return `None`.
#
# Finally, we turn `rows` into a `DataFrame`.

# %%
import pandas as pd
professor_info = pd.DataFrame(rows)
professor_info
# Out:
#                  name  office                 email
# 0         Lubaba Alim  25-111    lfalim@calpoly.edu
# 1        Kelly Bodwin  25-106   kbodwin@calpoly.edu
# 2        Matt Carlton  25-101  mcarlton@calpoly.edu
# 3         Beth Chance  25-235   bchance@calpoly.edu
# 4          Nian Cheng  25-119    ncheng@calpoly.edu
# 5       Olga Dekhtyar     25-  odekhtya@calpoly.edu
# 6       Sinem Demirci  25-213  sdemirci@calpoly.edu
# 7           Jimmy Doi  25-108      jdoi@calpoly.edu
# 8        Samuel Frame  25-121    sframe@calpoly.edu
# 9         Frank Giron  25-207   frgiron@calpoly.edu
# 10       Hunter Glanz  25-111    hglanz@calpoly.edu
# 11    Billie-Jo Grant  25-119  bgrant02@calpoly.edu
# 12      Bret Holladay  25-122  bahollad@calpoly.edu
# 13           Mike Ion  25-216      mion@calpoly.edu
# 14   Felicia Korengel  25-215  fkorenge@calpoly.edu
# 15       Vance Larsen  25-129  vjlarsen@calpoly.edu
# 16         Ulric Lund  25-214     ulund@calpoly.edu
# 17     Charlotte Mann  25-201    czmann@calpoly.edu
# 18    Karen McGaughey  25-102  kmcgaugh@calpoly.edu
# 19     James Oksanish  25-216  joksanis@calpoly.edu
# 20       Zoe Rehnberg  25-109  zrehnber@calpoly.edu
# 21         Steve Rein  25-234     srein@calpoly.edu
# 22     Emily Robinson  25-103  erobin17@calpoly.edu
# 23         Kevin Ross  25-237    kjross@calpoly.edu
# 24           Soma Roy  25-104     soroy@calpoly.edu
# 25        Trevor Ruiz  25-236   truiz01@calpoly.edu
# 26     Anelise Sabbag  25-222   asabbag@calpoly.edu
# 27     Julia Schedler  25-212  jschedle@calpoly.edu
# 28     Maddie Schroth  25-223  mschroth@calpoly.edu
# 29     Sonja Schuster  25-119  sschuste@calpoly.edu
# 30      Jeffrey Sklar  25-110    jsklar@calpoly.edu
# 31      Heather Smith  25-112    hsmith@calpoly.edu
# 32   Allison Theobold  25-105  atheobol@calpoly.edu
# 33        John Walker  25-226   jwalker@calpoly.edu
# 34        Yi-Hui Wang  25-119   ywang59@calpoly.edu
# 35  Immanuel Williams  25-113  imwillia@calpoly.edu
# 36      Deniz Yenigün  25-129  dyenigun@calpoly.edu

# %% [markdown]
# Now this data is ready for further processing.

# %% [markdown]
# ## Ethical Quandary: `robots.txt`
#
# Web robots are crawling the web all the time. A website may want to restrict the robots from crawling specific pages. One reason is financial: each visit to a web page, by a human or a robot, costs the website money, and the website may prefer to save their limited bandwidth for human visitors. Another reason is privacy: a website may not want a search engine to preserve a snapshot of a page for all eternity.
#
# To specify what a web robot is and isn't allowed to crawl, most websites will place a text file named `robots.txt` in the top-level directory of the web server. For example, the Statistics department web page has a `robots.txt` file: https://statistics.calpoly.edu/robots.txt
#
# The format of the `robots.txt` file should be self-explanatory, but you can read a full specification of the standard here: http://www.robotstxt.org/robotstxt.html. As you scrape websites using your web robot, always check the `robots.txt` file first, to make sure that you are respecting the wishes of the website owner.

# %% [markdown]
# # Exercises

# %% [markdown]
# ### 1\. Modify the code above to also capture the phone number and office hours, then print out the updated dataframe below. Get rid of any extra characters or escape sequences such as "\n".

# %%
rows = []
for faculty in table.find_all("tr")[1:]:
    # Get all the cells in the row.
    cells = faculty.find_all("td")

    # The information we need is the text between tags.
    name_tag = cells[0].find("strong") or cells[0]
    name = name_tag.text.strip().replace('\n', '')

    link = cells[1].find("td")
    office = (cells[1].text if link is None else link.text).strip().replace('\n', '')

    email_tag = cells[3].find("a") or cells[3]
    email = email_tag.text.strip().replace('\n', '')

    phone_tag = cells[2].find("a") or cells[2]
    phone = phone_tag.text.strip().replace('\n', '')

    hours_tag = cells[4].find("td") or cells[4]
    hours = hours_tag.text.strip().replace('\n', '')

    # Append this data.
    rows.append({
        "name": name,
        "office": office,
        "email": email,
        "phone": phone,
        "office_hours": hours
    })
# https://realpython.com/python-strip/#how-to-use-pythons-strip-method-to-remove-whitespace-from-strings
# https://realpython.com/python-web-scraping-practical-introduction/

professor_info = pd.DataFrame(rows)
professor_info
# Out:
#                  name  office                 email     phone  \
# 0         Lubaba Alim  25-111    lfalim@calpoly.edu  756-2792
# 1        Kelly Bodwin  25-106   kbodwin@calpoly.edu  756-2450
# 2        Matt Carlton  25-101  mcarlton@calpoly.edu  756-7076
# 3         Beth Chance  25-235   bchance@calpoly.edu  756-2961
# 4          Nian Cheng  25-119    ncheng@calpoly.edu  756-1825
# 5       Olga Dekhtyar  25-130  odekhtya@calpoly.edu  756-6354
# 6       Sinem Demirci  25-213  sdemirci@calpoly.edu  756-0683
# 7           Jimmy Doi  25-108      jdoi@calpoly.edu  756-2901
# 8        Samuel Frame  25-121    sframe@calpoly.edu  756-5802
# 9         Frank Giron  25-207   frgiron@calpoly.edu  756-2759
# 10       Hunter Glanz  25-111    hglanz@calpoly.edu  756-2792
# 11    Billie-Jo Grant  25-119  bgrant02@calpoly.edu  756-1825
# 12      Bret Holladay  25-122  bahollad@calpoly.edu  756-2709
# 13           Mike Ion  25-216      mion@calpoly.edu  756-1892
# 14   Felicia Korengel  25-215  fkorenge@calpoly.edu  756-2738
# 15       Vance Larsen  25-129  vjlarsen@calpoly.edu  756-0895
# 16         Ulric Lund  25-214     ulund@calpoly.edu  756-6122
# 17     Charlotte Mann  25-201    czmann@calpoly.edu  756-1344
# 18    Karen McGaughey  25-102  kmcgaugh@calpoly.edu  756-6578
# 19     James Oksanish  25-216  joksanis@calpoly.edu  756-1892
# 20       Zoe Rehnberg  25-109  zrehnber@calpoly.edu  756-2783
# 21         Steve Rein  25-234     srein@calpoly.edu  756-2941
# 22     Emily Robinson  25-103  erobin17@calpoly.edu  756-2715
# 23         Kevin Ross  25-237    kjross@calpoly.edu  756-5739
# 24           Soma Roy  25-104     soroy@calpoly.edu  756-5250
# 25        Trevor Ruiz  25-236   truiz01@calpoly.edu  756-2776
# 26     Anelise Sabbag  25-222   asabbag@calpoly.edu  756-5562
# 27     Julia Schedler  25-212  jschedle@calpoly.edu  756-5877
# 28     Maddie Schroth  25-223  mschroth@calpoly.edu  756-6310
# 29     Sonja Schuster  25-119  sschuste@calpoly.edu  756-1825
# 30      Jeffrey Sklar  25-110    jsklar@calpoly.edu  756-6353
# 31      Heather Smith  25-112    hsmith@calpoly.edu  756-6128
# 32   Allison Theobold  25-105  atheobol@calpoly.edu  756-5529
# 33        John Walker  25-226   jwalker@calpoly.edu  756-7128
# 34        Yi-Hui Wang  25-119   ywang59@calpoly.edu  756-1825
# 35  Immanuel Williams  25-113  imwillia@calpoly.edu  756-2709
# 36      Deniz Yenigün  25-129  dyenigun@calpoly.edu  756-0895
#
#                                          office_hours
# 0                                      MWF 10:10-11am
# 1                                         TR 3:10-5pm
# 2      T-F 4:30-5:30pm; only on Zoom (link in Canvas)
# 3        MR 10-11amW 10-12pm & by appointmentCalendly
# 4    T 10:10-11am; 1-2pmR 10:10-11am & by appointment
# 5         TW 10:20-11:20amR 10:10-11:10amF 10:10-11am
# 6         M 11:10-12:50pm in personW 2:10-3:50pm Zoom
# 7                                  WF 10:20-12pm Zoom
# 8                                                 N/A
# 9                        MW 1-1:50pm T 6-6:50pm; Zoom
# 10                                                N/A
# 11                                           Calendly
# 12                     W 4:10-5pmR 7:10-8amF 7:10-9am
# 13                     R 2:30-3:30pm & by appointment
# 14                          TR 12:10-1:30pmW 1:10-2pm
# 15                                          MW 9-11am
# 16                 TR 10-11am; 1-2pm & by appointment
# 17        T 9:30-11amR 9-10am; 2-3pm & by appointment
# 18         MW 10:30-12pm; in personF 10:10-11am; Zoom
# 19                                    M-R 1:15-2:30pm
# 20                     M 9-10:30amT 9-10amF 9:30-11am
# 21         T 9-10amR 10-11am & by appointmentCalendly
# 22                           MW 1:10-2:30pmR 1:10-2pm
# 23  M 10:10-11amT 2:10-3pmW 1:30-2:30pmR 9:30-10:30am
# 24          W 10:10-11am; in personF 11:10-12pm; Zoom
# 25                                 T-R 12-2pmCalendly
# 26  MW 12:10-1pm; in personTF 8:10-9am; Zoom (Link...
# 27                                        TR 3:30-5pm
# 28           MW 8:10-9am; ZoomTR 12:10-1pm; in person
# 29                W 4:10-5pmR 11:10-12pm only on Zoom
# 30                           MW 1:10-2pmTR 10:10-11am
# 31   TR 12:15-1pmW 9:15-11amCalendly & by appointment
# 32                                        MR 2:10-3pm
# 33                                 Contact Instructor
# 34        W 10:30-11:30am; in personF 9:10-10am; Zoom
# 35                                           TR 2-4pm
# 36                                                N/A

# %% [markdown]
# ### 2\. Determine how many faculty member offices are on each floor of the 25 building using Python. The room number is provided by the last three digits of the "office" column. The floor is indicated by the first number of these three digits. For example, "25-110" means room 110 in building 25, which is on the first floor.

# %%
def get_floor(row):
    return row['office'][3]

professor_info['floor'] = professor_info.apply(get_floor, axis=1)
pd.DataFrame(professor_info['floor'].value_counts())
# Out:
#        count
# floor
# 1         22
# 2         15

# %% [markdown]
# ###  Difficult optional challenge: Write code to ask the user for a given day and time, then use the updated dataframe from \#1 above to output which professors are available at that time.

# %% [markdown]
# ### 3. Find a website with a nicely structured table or tables that you can scrape.
#
# A few things to consider: The more simplistic the website format, the easier it will be to scrape. For example, https://en.wikipedia.org/wiki/Wikipedia:WikiProject_Songs/500 would be easier than https://www.rollingstone.com/music/music-lists/best-songs-of-all-time-1224767/kanye-west-stronger-1224837/ to work with. You can decide how more of a challenge you want to make this. In general, Wikipedia has a lot of simply formatted tables.
#
# Don't scrape any site that you're unsure about. For example, don't scrape a list of government employees or anything that could even be perceived as sensitive, even if it's publicly online. Stick with things like rankings of music, movies, countries, etc.
#
# Lastly, make sure that the robots.txt file permits scraping. The site won't stop you, but do the right thing here.
#
# List the site that you're scraping in the cell below.

# %% [markdown]
# https://kworb.net/spotify/artist/2ApaG60P4r0yhBoDCGD8YG_songs.html

# %% [markdown]
# ### 4. Write code to scrape the site and do a light data analysis (light because I don't anticipate there being a ton of columns for us to analyze).
#
# Look at the HTML, identify what tags surround the text that you're looking for, and start writing code from there. Understand that no two scraping tasks will be exactly the same. HTML can be vastly different across different sites. This makes it difficult to give you any cookie cutter type of code here. It can be tricky but it shouldn't be much code.
#
# Once the scraping is working, do some data analysis on the data. For example, if using data for the top 500 songs of all time above, you could determine the top five most frequent artists on the list, or determine how many of the top 500 songs were written each decade.
#
# If stuck, use StackOverflow, ChatGPT, or me as resources. You might even consider using an alternate web scraper such as Scrapy or Selenium (more powerful than BeautifulSoup, usually overkill).

# %%
response = requests.get("https://kworb.net/spotify/artist/2ApaG60P4r0yhBoDCGD8YG_songs.html")
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")
tables = soup.find_all("table")
len(tables)
# Out:
# 2

# %%
table = tables[1]
table
# Out:
# <table class="addpos sortable" style="width: 530px;">
# <colgroup>
# <col class="col50"/>
# <col class="col300"/>
# <col class="col100"/>
# <col class="col80"/>
# </colgroup><thead><tr>
# <th class="text">Song Title</th>
# <th>Streams</th>
# <th>Daily</th>
# </tr></thead><tbody>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/52Bg6oaos7twR7IUtEpqcE" target="_blank">Between The Bars</a></div></td><td>245,288,237</td><td>93,278</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/7zVfEu1dEvRw4EkWoqrBkx" target="_blank">Say Yes</a></div></td><td>113,647,447</td><td>53,477</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/0Ziohm1Ku8E2yUDYoclfhO" target="_blank">Angeles</a></div></td><td>96,482,927</td><td>37,032</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/5AMrnF761nziCWUfjBgRUI" target="_blank">Waltz #2 (XO)</a></div></td><td>62,009,192</td><td>24,269</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/7I7O0huqjKrXHX0aaLuO5B" target="_blank">Needle in the Hay</a></div></td><td>55,155,029</td><td>20,171</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4HqRhdpxH9zFUkf1kzbr3H" target="_blank">Ballad Of Big Nothing</a></div></td><td>40,254,550</td><td>36,178</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4xfAVJL8R7mVYbDk8a9xOY" target="_blank">Somebody That I Used To Know</a></div></td><td>38,030,408</td><td>13,897</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/1Q0sk7b7PAGjgC3R5zyuWt" target="_blank">Pitseleh</a></div></td><td>26,538,341</td><td>11,563</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/1pTwsLvnN8xPULDGzRjnfd" target="_blank">Clementine</a></div></td><td>26,370,431</td><td>32,948</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/6tPiCU4LFsXUQPRIykOAnl" target="_blank">Son Of Sam</a></div></td><td>25,937,555</td><td>12,015</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4gRySBzWoWD2JqEFZnfPuX" target="_blank">Speed Trials</a></div></td><td>24,979,431</td><td>20,757</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4UPLlFF10U3St7PaaQGPgi" target="_blank">Twilight</a></div></td><td>22,477,361</td><td>14,192</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4zetUxeSCCDwrr1jJT0SuD" target="_blank">Miss Misery</a></div></td><td>22,350,495</td><td>20,090</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/1tmMGcpr8JwkYDOZEK7B2I" target="_blank">Alameda</a></div></td><td>21,865,668</td><td>18,186</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/3nkdVXnH4xC6f3YZS0C8pC" target="_blank">Everything Reminds Me Of Her</a></div></td><td>18,075,646</td><td>14,114</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/
td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4R4vIwuUXjNkfBj8qRyKV7" target="_blank">Big Decision - Live At Umbra Penumbra - September 17th, 1994</a></div></td><td>295,133</td><td>221</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4Xq60V8m5eXAqeee1i4PFH" target="_blank">Pretty Mary K - Alternate Version</a></div></td><td>278,053</td><td>186</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/6I69aqSGGevilQIGAnEv2o" target="_blank">No Name #1 - Live At Umbra Penumbra - September 17th, 1994</a></div></td><td>274,551</td><td>253</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4lQayhDXI7YQGSId92GEz8" target="_blank">Alphabet Town - Live At Umbra Penumbra - September 17th, 1994</a></div></td><td>269,426</td><td>255</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/4SpmUsRegrXOLChYf3z8fS" target="_blank">Condor Ave - Live At Umbra Penumbra - September 17th, 1994</a></div></td><td>268,568</td><td>250</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/7wOPqyQxn0oDhNq25GaKzb" target="_blank">Half Right - Live At Umbra Penumbra - September 17th, 1994</a></div></td><td>267,165</td><td>256</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/5T1VXG7LkdQsBSlnoPLBN5" target="_blank">Bottle Up &amp; Explode! - Early Version</a></div></td><td>259,823</td><td>214</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/3x8ZC432FXVl9pTrQ5bvgz" target="_blank">Crazy Fucker - Live At Umbra Penumbra - September 17th, 1994</a></div></td><td>256,474</td><td>244</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/2sqNE2NEGkTTc16E5Scxkv" target="_blank">No Name #4 - Live At Umbra Penumbra - September 17th, 1994</a></div></td><td>244,756</td><td>236</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/3FURaD1rMYSU0zFIcMgfzL" target="_blank">Alameda - Alternative Version</a></div></td><td>218,351</td><td>81</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/3JtzPizwE5YbV1B60Xi4SC" target="_blank">Baby Britain - Remix</a></div></td><td>199,871</td><td>159</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/0RLflnayEwYhKrxbPO49IU" target="_blank">Waltz #2 - Radio Edit</a></div></td><td>196,684</td><td>143</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/5tB7gB5FcSKTrz5XBDKMrL" target="_blank">Ballad of Big Nothing - Alternate Vocal</a></div></td><td>189,289</td><td>89</td></tr>
# <tr><td class="text"><div><a href="https://open.spotify.com/track/0vGGGnjP8hY8C7O74UIV4S" target="_blank">Punch and Judy - Other Version</a></div></td><td>141,845</td><td>51</td></tr>
# </tbody></table>

# %%
rows = []
for songs in table.find_all("tr")[1:]:
    # Get all the cells in the row.
    cells = songs.find_all("td")

    # The information we need is the text between tags.
    link = cells[0].find("strong")
    name = cells[0].text if link is None else link.text

    totstreams_tag = cells[1].find("td") or cells[1]
    totstreams = totstreams_tag.text

    dailstreams_tag = cells[2].find("td") or cells[2]
    dailstreams = dailstreams_tag.text

    # Append this data.
    rows.append({
        "song name": name,
        "total streams": totstreams,
        "daily streams": dailstreams
    })

# %%
elliottsmith = pd.DataFrame(rows)
#pd.set_option('display.max_rows', None)
elliottsmith.head()
# Out:
#            song name total streams daily streams
# 0   Between The Bars   245,288,237        93,278
# 1            Say Yes   113,647,447        53,477
# 2            Angeles    96,482,927        37,032
# 3      Waltz #2 (XO)    62,009,192        24,269
# 4  Needle in the Hay    55,155,029        20,171

# %%
elliottsmith.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   song name      160 non-null    object
#  1   total streams  160 non-null    object
#  2   daily streams  160 non-null    object
# dtypes: object(3)
# memory usage: 3.9+ KB

# %%
elliottsmith['daily streams'] = elliottsmith['daily streams'].str.replace(',', '').astype(int)
elliottsmith['total streams'] = elliottsmith['total streams'].str.replace(',', '').astype(int)
elliottsmith['daily streams'] = elliottsmith['daily streams'].astype(int) 
elliottsmith['total streams'] = elliottsmith['total streams'].astype(int)

# %%
elliottsmith.dtypes
# Out:
# song name        object
# total streams     int32
# daily streams     int32
# dtype: object

# %%
print("Total streams (daily): ", elliottsmith['daily streams'].sum())
# Out:
# Total streams (daily):  713834

# %%
print("Total streams (all time): ", elliottsmith['total streams'].sum())
# Out:
# Total streams (all time):  1385367855

# %%
print("Average daily streams per song: ", elliottsmith['daily streams'].mean())
# Out:
# Average daily streams per song:  4461.4625

# %%
print("Average total streams per song: ", elliottsmith['total streams'].mean())
# Out:
# Average total streams per song:  8658549.09375

# %%
elliottsmith.head(10)
# Out:
#                       song name  total streams  daily streams
# 0              Between The Bars      245288237          93278
# 1                       Say Yes      113647447          53477
# 2                       Angeles       96482927          37032
# 3                 Waltz #2 (XO)       62009192          24269
# 4             Needle in the Hay       55155029          20171
# 5         Ballad Of Big Nothing       40254550          36178
# 6  Somebody That I Used To Know       38030408          13897
# 7                      Pitseleh       26538341          11563
# 8                    Clementine       26370431          32948
# 9                    Son Of Sam       25937555          12015

# %%
dailypopular = elliottsmith.sort_values(by="daily streams", ascending=False)
dailypopular.head(10)
# Out:
#                 song name  total streams  daily streams
# 0        Between The Bars      245288237          93278
# 1                 Say Yes      113647447          53477
# 2                 Angeles       96482927          37032
# 5   Ballad Of Big Nothing       40254550          36178
# 8              Clementine       26370431          32948
# 3           Waltz #2 (XO)       62009192          24269
# 10           Speed Trials       24979431          20757
# 4       Needle in the Hay       55155029          20171
# 12            Miss Misery       22350495          20090
# 13                Alameda       21865668          18186

# %% [markdown]
# When sorting the top 10 songs by total streams and daily streams, you can see which songs are more popular historically and which songs are more relevant today.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["font.family"] = "Comic Sans MS"
top_ten_daily = elliottsmith.sort_values(by="daily streams", ascending=False).head(10)
palette = sns.color_palette("mako", n_colors=len(top_ten_daily))
plt.figure(figsize=(8, 6))
plt.barh(top_ten_daily['song name'], top_ten_daily['daily streams'], color=sns.color_palette("mako", 2)[0])
plt.xlabel('Daily Streams')
plt.ylabel('Song Name')
plt.title('Top 10 Elliott Smith Songs by Daily Streams')


plt.show()

# %%
def songtype(song):
    if 'Demo' in song:
        return "demo"
    elif 'Live' in song:
        return "live"
    else:
        return "not demo or live"

elliottsmith['song type'] = elliottsmith['song name'].apply(songtype)
pd.set_option('display.max_rows', None)
elliottsmith
# Out:
#                                              song name  total streams  \
# 0                                     Between The Bars      245288237
# 1                                              Say Yes      113647447
# 2                                              Angeles       96482927
# 3                                        Waltz #2 (XO)       62009192
# 4                                    Needle in the Hay       55155029
# 5                                Ballad Of Big Nothing       40254550
# 6                         Somebody That I Used To Know       38030408
# 7                                             Pitseleh       26538341
# 8                                           Clementine       26370431
# 9                                           Son Of Sam       25937555
# 10                                        Speed Trials       24979431
# 11                                            Twilight       22477361
# 12                                         Miss Misery       22350495
# 13                                             Alameda       21865668
# 14                        Everything Reminds Me Of Her       18075646
# 15                                         Rose Parade       16843229
# 16                                   Angel in the Snow       16367159
# 17                      Everything Means Nothing To Me       14161014
# 18                         Miss Misery - Early Version       13898935
# 19                                      Pictures Of Me       13876996
# 20                                        Baby Britain       13751552
# 21                                     A Fond Farewell       13420451
# 22                                             2:45 AM       12748001
# 23                                                L.A.       12044572
# 24                                    Independence Day       11997433
# 108                      Son Of Sam - Acoustic Version        1199036
# 109                                        Almost Over        1180687
# 110                                          Fear City        1124770
# 111                                          True Love         981324
# 112                              My New Freedom - Live         849373
# 113                                       Division Day         830822
# 114                            Waltz #1 - Demo Version         799027
# 115                    Plainclothes Man - Solo Version         755159
# 116                    Untitled Melancholy Song - Demo         754731
# 117                                          Some Song         734816
# 118         Bottle Up And Explode! - Alternate Version         688273
# 119                              Pictures Of Me - Live         670741
# 120      Say Yes - Live At Yo Yo A Go Go Festival/1997         612102
# 121  Miss Misery - Live On Late Night With Conan O'...         610807
# 122                       Happiness - Acoustic Version         610014
# 123                                           Figure 8         603189
# 124                                   Some Song - Live         600512
# 125                                   The Enemy Is You         595616
# 126                                 Rose Parade - Live         556642
# 127                          New Monkey - Instrumental         541684
# 128                                      A Living Will         482239
# 129                         Don't Call Me Billy - Demo         481277
# 130                     Coast To Coast - Early Version         470178
# 131                         I Can't Answer You Anymore         469827
# 132                             Unknown (Instrumental)         462721
# 133                     Untitled Soft Song In F - Demo         446331
# 134                    Some Song - Alternative Version         442017
# 135                                 How To Take A Fall         436747
# 136                        Unknown Song (Instrumental)         432339
# 137                          Hamburgers - Instrumental         430642
# 138  Some Song - Live At Umbra Penumbra - September...         416173
# 139                      The Last Hour - Early Version         412999
# 140                                          Our Thing         403178
# 141                                         No Name #6         397511
# 142                                     I Love My Room         380750
# 143  No Confidence Man - Live At Umbra Penumbra - S...         355496
# 144  Whatever (Folk Song In C) - Live At Umbra Penu...         341133
# 145                      Angeles - Alternative Version         319408
# 146  Big Decision - Live At Umbra Penumbra - Septem...         295133
# 147                  Pretty Mary K - Alternate Version         278053
# 148  No Name #1 - Live At Umbra Penumbra - Septembe...         274551
# 149  Alphabet Town - Live At Umbra Penumbra - Septe...         269426
# 150  Condor Ave - Live At Umbra Penumbra - Septembe...         268568
# 151  Half Right - Live At Umbra Penumbra - Septembe...         267165
# 152               Bottle Up & Explode! - Early Version         259823
# 153  Crazy Fucker - Live At Umbra Penumbra - Septem...         256474
# 154  No Name #4 - Live At Umbra Penumbra - Septembe...         244756
# 155                      Alameda - Alternative Version         218351
# 156                               Baby Britain - Remix         199871
# 157                              Waltz #2 - Radio Edit         196684
# 158            Ballad of Big Nothing - Alternate Vocal         189289
# 159                     Punch and Judy - Other Version         141845
#
#      daily streams         song type
# 0            93278  not demo or live
# 1            53477  not demo or live
# 2            37032  not demo or live
# 3            24269  not demo or live
# 4            20171  not demo or live
# 5            36178  not demo or live
# 6            13897  not demo or live
# 7            11563  not demo or live
# 8            32948  not demo or live
# 9            12015  not demo or live
# 10           20757  not demo or live
# 11           14192  not demo or live
# 12           20090  not demo or live
# 13           18186  not demo or live
# 14           14114  not demo or live
# 15           10223  not demo or live
# 16            5517  not demo or live
# 17           10331  not demo or live
# 18            2527  not demo or live
# 19            7636  not demo or live
# 20            4292  not demo or live
# 21           11543  not demo or live
# 22            7283  not demo or live
# 23            6735  not demo or live
# 24            6038  not demo or live
# 25            7751  not demo or live
# 26           10386  not demo or live
# 27            8065  not demo or live
# 28            5603  not demo or live
# 29            5938  not demo or live
# 30            4939  not demo or live
# 31            4398  not demo or live
# 32            3032  not demo or live
# 33            3077  not demo or live
# 34            4066  not demo or live
# 35            2067  not demo or live
# 36            3286  not demo or live
# 37            4702  not demo or live
# 38            2126  not demo or live
# 39            3457  not demo or live
# 40            2280  not demo or live
# 41            4312  not demo or live
# 42            1633  not demo or live
# 43            3149  not demo or live
# 44            2716  not demo or live
# 45            4384  not demo or live
# 46            3404  not demo or live
# 47            2056  not demo or live
# 48            3050  not demo or live
# 49            5410  not demo or live
# 50            4204  not demo or live
# 51            2286  not demo or live
# 52            3541  not demo or live
# 53            2434  not demo or live
# 54            3086  not demo or live
# 55            2609  not demo or live
# 56            2555  not demo or live
# 57            3405  not demo or live
# 58            2734  not demo or live
# 59            2626  not demo or live
# 60            3474  not demo or live
# 61            2501  not demo or live
# 62            4773  not demo or live
# 63            2332  not demo or live
# 64            2682  not demo or live
# 65            2207  not demo or live
# 66            3453  not demo or live
# 67            1998  not demo or live
# 68            2044  not demo or live
# 69            2087  not demo or live
# 70            2310  not demo or live
# 71            1487  not demo or live
# 72            1731  not demo or live
# 73            2961  not demo or live
# 74            1237  not demo or live
# 75            1371  not demo or live
# 76            2110  not demo or live
# 77            1520  not demo or live
# 78            1248  not demo or live
# 79            1941  not demo or live
# 80            1405  not demo or live
# 81            1123  not demo or live
# 82            1453  not demo or live
# 83            1145  not demo or live
# 84            1111  not demo or live
# 85            1717  not demo or live
# 86             685  not demo or live
# 87            1558  not demo or live
# 88             871  not demo or live
# 89            1047  not demo or live
# 90            1464  not demo or live
# 91             994  not demo or live
# 92             915              demo
# 93             850  not demo or live
# 94             740  not demo or live
# 95            1227  not demo or live
# 96             803  not demo or live
# 97             744  not demo or live
# 98             709  not demo or live
# 99             733  not demo or live
# 100            733  not demo or live
# 101            641  not demo or live
# 102            707  not demo or live
# 103            573  not demo or live
# 104            527  not demo or live
# 105            455  not demo or live
# 106            488  not demo or live
# 107            490              live
# 108            606  not demo or live
# 109            433  not demo or live
# 110            385  not demo or live
# 111            466  not demo or live
# 112            320              live
# 113            381  not demo or live
# 114            406              demo
# 115            289  not demo or live
# 116            240              demo
# 117            349  not demo or live
# 118            299  not demo or live
# 119            196              live
# 120            224              live
# 121            162              live
# 122            529  not demo or live
# 123            324  not demo or live
# 124            202              live
# 125            509  not demo or live
# 126            192              live
# 127            221  not demo or live
# 128            382  not demo or live
# 129             78              demo
# 130            133  not demo or live
# 131            340  not demo or live
# 132            112  not demo or live
# 133            116              demo
# 134            372  not demo or live
# 135            409  not demo or live
# 136            110  not demo or live
# 137             94  not demo or live
# 138            303              live
# 139            160  not demo or live
# 140            296  not demo or live
# 141            255  not demo or live
# 142            120  not demo or live
# 143            318              live
# 144            296              live
# 145            135  not demo or live
# 146            221              live
# 147            186  not demo or live
# 148            253              live
# 149            255              live
# 150            250              live
# 151            256              live
# 152            214  not demo or live
# 153            244              live
# 154            236              live
# 155             81  not demo or live
# 156            159  not demo or live
# 157            143  not demo or live
# 158             89  not demo or live
# 159             51  not demo or live
