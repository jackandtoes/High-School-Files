# %%
#wawa = [80, 100, 30, 10, 550]
# miles per hour
#mps = []
#for num in wawa:
 #   mps = num * 
  #  celcius = (num - 32) * 5/9
   # temp_c.append(celcius)
raw_list = [80, 100, 30, 10, 550]
converted_list = [(x*5280)/]
