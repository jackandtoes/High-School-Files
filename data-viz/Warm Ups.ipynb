# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Day 3 Warmups

# %% [markdown]
# <i> Your text here <i>

# %%
name = "Zac"
addressnum = 149
addressname = "Topsail Lane"
weight = 250.79

# %%
print('My name is ' + str(name) + ". I live at " + str(addressnum) + " " + addressname + ". I weigh " + str(weight) + " lbs.")
# Out:
# My name is Zac. I live at 149 Topsail Lane. I weigh 250.79 lbs.

# %%
radius = 4.5
circlearea = radius * radius * 3.14159

# %%
print (round(circlearea,2))
# Out:
# 63.62

# %%
round(circlearea,2)
# Out:
# 63.62

# %%
corcle = radius**2 * 3.14159

# %%
print (corcle)
# Out:
# 63.617197499999996
