# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:#2462C0; font-style:bold"><br>
# Pandas Tutorial</p><br>
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# *pandas* is a Python library for data analysis. It offers a number of data exploration, cleaning and transformation operations that are critical in working with data in Python.
#
# *pandas* builds upon *numpy* and *scipy* provides easy-to-use data structures and data manipulation functions with integrated indexing.

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# Importing pandas</p>
# <br>

# %%
import pandas as pd
pd.options.mode.chained_assignment = None # Suppresses a new warning in Pandas, more info at https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# Introduction to pandas Data Structures</p>
# <br>
#
# Core components of pandas: Series and DataFrames.
# A Series is essentially a column, and a DataFrame is a multi-dimensional table made up of a collection of Series.
#
# ![image.png](attachment:image.png)
# Image source: https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/

# %% [markdown]
# Here we create some fictitious data manually.

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2],
    'bananas': [10, 2, 9, 4]
}
data
# Out:
# {'apples': [3, 2, 0, 1], 'oranges': [0, 3, 7, 2], 'bananas': [10, 2, 9, 4]}

# %% [markdown]
# The next command will convert the data to a pandas DataFrame called purchases. We now have all of the functionality of the DataFrame (and it looks nicer too!).

# %%
purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges  bananas
# 0       3        0       10
# 1       2        3        2
# 2       0        7        9
# 3       1        2        4

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# Loading Data into Pandas</p>

# %% [markdown]
# It's uncommon to create your own dataframe manually, as was done above. Most of the time, you'd be importing data from an Excel file, comma-separated value (csv) file, or a less common type like a json. You can also query a database and pull the results directly into a DataFrame, but that's beyond the scope of this course.

# %% [markdown]
# In this tutorial, we will load and examine a dataset of about 4600 Bigfoot sightings from around the United States.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Specifying the location of the data file correctly is important. In the example below, '.' refers to the current directory, so this is saying to start in the directory of this Jupyter Notebook, find the 'data' subdirectory, then find the 'bigfoot_reports.csv' file in the subdirectory.

# %%
bigfoot = pd.read_csv('./data/bigfoot_reports.csv', sep=',')

# %% [markdown]
# Let's take a look at the data. We can use the head command to see the first n rows. If you leave the parameter blank, it assumes that you want to view 5 rows. You can also specify a number of rows in parentheses.

# %%
bigfoot.head()
# Out:
#           state             county  latitude  longitude  month   day    year  \
# 0  Pennsylvania  Clearfield County  41.01865  -78.37700    1.0  14.0  1921.0
# 1     Louisiana   Avoyelles Parish  31.08774  -91.84467   10.0  14.0  1925.0
# 2         Texas        Leon County  31.40444  -95.70861    9.0  30.0  1930.0
# 3       Indiana     Warrick County  38.01000  -87.32030    8.0  16.0  1937.0
# 4         Texas       Ellis County  32.51750  -96.80417    6.0  30.0  1938.0
#
#   classification  temperature_mid  dew_point  ...  cloud_cover  moon_phase  \
# 0        Class A              NaN        NaN  ...          NaN         NaN
# 1        Class B              NaN        NaN  ...          NaN         NaN
# 2        Class B            74.49      61.85  ...         0.24        0.28
# 3        Class A              NaN        NaN  ...          NaN         NaN
# 4        Class B              NaN        NaN  ...          NaN         NaN
#
# ...

# %%
bigfoot.head(10)
# Out:
#           state             county  latitude  longitude  month   day    year  \
# 0  Pennsylvania  Clearfield County  41.01865  -78.37700    1.0  14.0  1921.0
# 1     Louisiana   Avoyelles Parish  31.08774  -91.84467   10.0  14.0  1925.0
# 2         Texas        Leon County  31.40444  -95.70861    9.0  30.0  1930.0
# 3       Indiana     Warrick County  38.01000  -87.32030    8.0  16.0  1937.0
# 4         Texas       Ellis County  32.51750  -96.80417    6.0  30.0  1938.0
# 5    Washington      Yakima County  46.24639 -120.86810   10.0  15.0  1941.0
# 6      Oklahoma      Harmon County  34.73153  -99.81514    4.0   1.0  1942.0
# 7      Michigan       Alger County  46.35503  -86.97000    7.0   1.0  1944.0
# 8    California    Siskiyou County  41.82417 -122.99580    8.0   1.0  1944.0
# 9       Florida      Putnam County  29.77295  -81.68295    7.0   1.0  1947.0
#
#   classification  temperature_mid  dew_point  ...  cloud_cover  moon_phase  \
# ...

# %% [markdown]
# There's an analogous tail function as well to see the end of a dataframe. Many don't use this function, but I find it very useful since problematic data is often found at the end of a file (truncated rows, missing data, etc.).

# %%
bigfoot.tail()
# Out:
#            state             county  latitude  longitude  month  day  year  \
# 4581     Wyoming  Sweetwater County       NaN        NaN    NaN  NaN   NaN
# 4582     Wyoming       Teton County       NaN        NaN    NaN  NaN   NaN
# 4583     Wyoming       Teton County       NaN        NaN    NaN  NaN   NaN
# 4584     Wyoming    Washakie County       NaN        NaN    NaN  NaN   NaN
# 4585  California  Stanislaus County       NaN        NaN    NaN  NaN   NaN
#
#      classification  temperature_mid  dew_point  ...  cloud_cover  moon_phase  \
# 4581        Class B              NaN        NaN  ...          NaN         NaN
# 4582        Class A              NaN        NaN  ...          NaN         NaN
# 4583        Class A              NaN        NaN  ...          NaN         NaN
# 4584        Class B              NaN        NaN  ...          NaN         NaN
# 4585        Class A              NaN        NaN  ...          NaN         NaN
#
# ...

# %% [markdown]
# "NaN" stands for "not a number" and refers to a blank value in pandas. We will deal with the missing values later.

# %% [markdown]
# For a dataframe with a large number of columns, Pandas hides some of the middle columns for readability. If you want Pandas to display all columns when using the head or tail function, run the line of code below. This tweak will persist throughout the rest of the notebook.

# %%
pd.options.display.max_columns = None

# %% [markdown]
# If you run this command and have second thoughts, you can restore it to the default via:
#
# <b>pd.reset_option("display.max_columns")</b>
#
# You will have to restart the kernel and run all cells to prompt the change.

# %% [markdown]
# I have already removed a few columns that aren't relevant to the sightings, but let's get a full list of what columns are in this dataset using the columns command.

# %%
bigfoot.columns
# Out:
# Index(['state', 'county', 'latitude', 'longitude', 'month', 'day', 'year',
#        'classification', 'temperature_mid', 'dew_point', 'humidity',
#        'cloud_cover', 'moon_phase', 'precip_intensity', 'summary', 'uv_index',
#        'visibility', 'wind_bearing', 'wind_speed', 'observed',
#        'location_details'],
#       dtype='object')

# %% [markdown]
# The UV index doesn't seem too relevant here. We already have some other relevant weather parameters. Let's get rid of it with the del command.

# %%
del bigfoot['uv_index']

# %% [markdown]
# You can drop multiple columns at once...<br><br>
# If df is the dataframe name and A and B are the columns you want to get rid of, use the drop function and provide a list of the columns to drop:
#
# df = df.drop(['A', 'B'], axis=1)

# %% [markdown]
# We can also examine the shape and size of the dataframe. Shape provides the number of rows and columns, in that order. Size gives the total number of values (rows * columns).

# %%
bigfoot.shape
# Out:
# (4586, 20)

# %%
bigfoot.size
# Out:
# 91720

# %% [markdown]
# You can view how many unique values occur in each column with the nunique function. This can give us a sense for whether there's erroneous data in the dataset. For example, there should only be a maximum of 12 unique months, whereas it makes sense for the latitude/longitude values to largely be unique since they were captured to five decimal places. For this dataset, there doesn't seem to be any major quality issues indicated.

# %%
bigfoot.nunique()
# Out:
# state                 49
# county              1005
# latitude            3587
# longitude           3576
# month                 12
# day                   31
# year                  78
# classification         3
# temperature_mid     2795
# dew_point           2678
# humidity              83
# cloud_cover          101
# moon_phase           100
# precip_intensity     326
# summary              275
# visibility           554
# wind_bearing         360
# wind_speed          1118
# observed            4552
# location_details    3815
# dtype: int64

# %% [markdown]
# Duplicates can also cause issues with datasets, as pandas will include them by default. This could throw off all sorts of numerical calculations. Here's how to filter rows that are duplicates of one another. Note that you might not always want to filter duplicates (for example, if you were tracking all items ordered at a restaurant in a given day).

# %%
bigfoot = bigfoot.drop_duplicates()

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# Inplace Operations</p>
#
# If you make a change to a DataFrame and you want it to be permanent, you must save it back in the DataFrame. For example,
#
# bigfoot.drop_duplicates()
#
# will show you the result of dropping duplicates when you run the command, but it will not save the change in the bigfoot dataframe.
#
# To save the change, you must do:
#
# bigfoot = bigfoot.drop_duplicates()
#
# An alternative that you will often see online is to use the inplace keyword. This keyword means to make the change permanently without requiring you to save the change manually with the equals sign. The example below does the same thing as the prior code cell.

# %%
bigfoot.drop_duplicates(inplace=True)

# %% [markdown]
# We could look at how many rows were deleted by running the shape command again. It looks like only one row was a duplicate (original shape: 4586 rows, new shape: 4585 rows).

# %%
bigfoot.shape
# Out:
# (4585, 20)

# %% [markdown]
# Sometimes you might want to drop duplicates, but in instances where a subset of the columns match one another. For example, the following would keep the first row in which a given month, day, and year occurred in the data, but filter out the others. Don't actually run this because this would imply that we should only allow for Bigfoot sighting a day.
#
# bigfoot = bigfoot.drop_duplicates(subset=['month', 'day', 'year'], keep='first')

# %% [markdown]
# A lot of issues come from Python making bad assumptions about the data type of the dataframe. If you want to check the data type of each column, use the dtypes command.

# %%
bigfoot.dtypes
# Out:
# state                object
# county               object
# latitude            float64
# longitude           float64
# month               float64
# day                 float64
# year                float64
# classification       object
# temperature_mid     float64
# dew_point           float64
# humidity            float64
# cloud_cover         float64
# moon_phase          float64
# precip_intensity    float64
# summary              object
# visibility          float64
# wind_bearing        float64
# wind_speed          float64
# observed             object
# location_details     object
# dtype: object

# %% [markdown]
# When we try to calculate means, percentiles, and other statistics, null values can cause issues. In the following cell, we remove all rows that have 'NaN' for the month. Note that we are saving it to a new dataframe. This ensures that we can use the original full dataset for any desired calculations later in this notebook. We use the copy function to avoid any future linkage between changes to bigfoot and changes to bigfoot_valid_dates.

# %%
bigfoot_valid = bigfoot.copy().dropna(subset = ['month'])

# %% [markdown]
# We can also use the dropna function to remove rows that have at least one blank value in the column. Be careful doing this. A dataset can still be good even if not every column is populated. For example, if recording the weather on a tranquil day, an observer might leave the precipitation type column blank. That doesn't mean the entire observation should be removed!

# %%
bigfoot_full_rows = bigfoot.copy().dropna()

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# Important Reminder!!!</p>
#
# For a given session, the results of all code run in a Jupyter notebook is remembered unless you go to "Cell > Run All" at the top of the screen. As a result, if you run the cell above twice, it will fail the second time because uv_index is removed the first time you run it and it no longer exists as a column.
#
# If you're doing some work in Pandas and get an unexpected error that you can't figure out, you likely messed up a column along the way and don't realize it. Try rerunning all cells to start with a fresh slate.

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#3CB371; font-style:bold">
# Checkpoint</p>

# %% [markdown]
# * Delete the wind_bearing column.

# %%
del bigfoot_valid['wind_bearing']
bigfoot_valid.columns
# Out:
# Index(['state', 'county', 'latitude', 'longitude', 'month', 'day', 'year',
#        'classification', 'temperature_mid', 'dew_point', 'humidity',
#        'cloud_cover', 'moon_phase', 'precip_intensity', 'summary',
#        'visibility', 'wind_speed', 'observed', 'location_details'],
#       dtype='object')

# %% [markdown]
# Most columns above are intuitive, but here is info on some that aren't:<br>
# classification = Class A: I saw bigfoot, Class B: I saw evidence of bigfoot, Class C: Somebody told me they saw bigfoot

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# Basic DataFrame operations</p>

# %% [markdown]
# <p style="font-family: Arial; font-size:1.25em;color:#2462C0; font-style:bold">
# Displaying column data</p>

# %% [markdown]
# Show the data for the column called 'state'.

# %%
bigfoot_valid['state']
# Out:
# 0       Pennsylvania
# 1          Louisiana
# 2              Texas
# 3            Indiana
# 4              Texas
#             ...
# 3653      Washington
# 3654           Idaho
# 3655            Ohio
# 3656           Texas
# 3657        Illinois
# Name: state, Length: 3658, dtype: object

# %% [markdown]
# There is another notation that we can use to select a column from a DataFrame. There is no fundamental difference between the two approaches and it is a matter of preference. However, if there is a space in the column name, you should use the first notation.

# %%
bigfoot_valid.state
# Out:
# 0       Pennsylvania
# 1          Louisiana
# 2              Texas
# 3            Indiana
# 4              Texas
#             ...
# 3653      Washington
# 3654           Idaho
# 3655            Ohio
# 3656           Texas
# 3657        Illinois
# Name: state, Length: 3658, dtype: object

# %% [markdown]
# <p style="font-family: Arial; font-size:1.25em;color:#2462C0; font-style:bold">
# Creating new column using basic calculations</p>

# %% [markdown]
# Create a new column called county_state that concatenates the county and state.

# %%
bigfoot_valid['county_state'] = bigfoot_valid['county'] + ", " + bigfoot_valid['state']
bigfoot_valid['county_state'].head()
# Out:
# 0    Clearfield County, Pennsylvania
# 1        Avoyelles Parish, Louisiana
# 2                 Leon County, Texas
# 3            Warrick County, Indiana
# 4                Ellis County, Texas
# Name: county_state, dtype: object

# %% [markdown]
# Create a new column called observed_length that captures the length of the string in the observed column (aka how long is the descriptive text).

# %%
bigfoot_valid['observed_length'] = bigfoot_valid['observed'].str.len()
bigfoot_valid['observed_length'].head()
# Out:
# 0       NaN
# 1    1138.0
# 2    1006.0
# 3       NaN
# 4    2509.0
# Name: observed_length, dtype: float64

# %% [markdown]
# <p style="font-family: Arial; font-size:1.25em;color:#2462C0; font-style:bold">
# Changing data types</p>

# %% [markdown]
# Note that using dtypes told us that month, day, and year were being interpreted as floats. In the example below, we show how to convert them to integers.

# %%
bigfoot_valid['month'] = bigfoot_valid['month'].astype('int') 
bigfoot_valid['day'] = bigfoot_valid['day'].astype('int') 
bigfoot_valid['year'] = bigfoot_valid['year'].astype('int')

# %% [markdown]
# We could check that it worked by calling dtypes again.

# %%
bigfoot_valid.dtypes
# Out:
# state                object
# county               object
# latitude            float64
# longitude           float64
# month                 int32
# day                   int32
# year                  int32
# classification       object
# temperature_mid     float64
# dew_point           float64
# humidity            float64
# cloud_cover         float64
# moon_phase          float64
# precip_intensity    float64
# summary              object
# visibility          float64
# wind_speed          float64
# observed             object
# location_details     object
# county_state         object
# observed_length     float64
# dtype: object

# %% [markdown]
# You can rename a column with the rename function...

# %%
bigfoot_valid = bigfoot_valid.rename(columns={'temperature_mid': 'temp_f'})

# %%
bigfoot_valid.columns
# Out:
# Index(['state', 'county', 'latitude', 'longitude', 'month', 'day', 'year',
#        'classification', 'temp_f', 'dew_point', 'humidity', 'cloud_cover',
#        'moon_phase', 'precip_intensity', 'summary', 'visibility', 'wind_speed',
#        'observed', 'location_details', 'county_state', 'observed_length'],
#       dtype='object')

# %% [markdown]
# You can rename multiple columns at once. Just provide the columns argument a list of key-value pairs with the old column name and the new name.

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# Creating New Columns using Conditions</p>

# %% [markdown]
# There are many times where you might want to create a new value in a row based on values in another row. For example, maybe given a month you want to output the season, or given a temp_f you want to categorize the day as cold, mild, or hot. The apply function helps us do this.

# %%
def get_season(month):
    if month <= 3:
        return 'Winter'
    elif month <= 6:
        return 'Spring'
    elif month <= 9:
        return 'Summer'
    else:
        return 'Fall'

# Provide the new column name on left side below. On the right side, tell Python what column you'll be calling 
# the function on, then use apply to call it.

bigfoot_valid['season'] = bigfoot_valid['month'].apply(get_season)

# %% [markdown]
# Let's see if it worked by grabbing the first five rows of data. Let's only look at the month and the season that it calculated.

# %%
bigfoot_valid[['month','season']].head()
# Out:
#    month  season
# 0      1  Winter
# 1     10    Fall
# 2      9  Summer
# 3      8  Summer
# 4      6  Spring

# %% [markdown]
# Now let's bin the temperatures into hot, mild, and cold categories.

# %%
def set_temperature_category(num):
    if num >= 80:
        return 'Hot'
    elif num >= 40:
        return 'Mild'
    else:
        return 'Cold'

# This calls the function. On the left side, we specify the name of the new column.
# On the right side, we specify the column that we're using, then call the apply function and provide 
# it the function name that we're calling.

bigfoot_valid['temp_category'] = bigfoot_valid['temp_f'].apply(set_temperature_category)

# %% [markdown]
# Here's a more complicated example that uses multiple columns as input to the function. In this example, we create a new column called condition_quality that returns 'Good' if the cloud_cover is less than 0.5 and the visibility is at least 3, and returns 'Poor' otherwise.

# %%
def determine_quality(row):
    if row['cloud_cover'] < 0.5 and row['visibility'] > 3:
        return 'Good'
    else:
        return 'Bad'

bigfoot_valid['condition_quality'] = bigfoot_valid.apply(determine_quality, axis=1)

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#3CB371; font-style:bold">
# Checkpoint</p>

# %% [markdown]
# * Create a new column called temp_c that takes the temp_f in Fahrenheit and converts it to the Celsius equivalent.

# %%
bigfoot_valid['temp_c'] = (bigfoot_valid['temp_f']-32)*(5/9)
bigfoot_valid[['temp_c','temp_f']].head(10)
# Out:
#       temp_c  temp_f
# 0        NaN     NaN
# 1        NaN     NaN
# 2  23.605556   74.49
# 3        NaN     NaN
# 4        NaN     NaN
# 5  14.427778   57.97
# 6  17.222222   63.00
# 7  18.094444   64.57
# 8        NaN     NaN
# 9  25.277778   77.50

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Descriptive Statistics</h1>
#
# Let's look how the temperatures are distributed! Describe will show statistics for the specified column(s).

# %%
bigfoot_valid['temp_f'].describe()
# Out:
# count    3645.000000
# mean       59.686560
# std        15.822718
# min        -7.960000
# 25%        49.090000
# 50%        61.820000
# 75%        71.900000
# max        94.690000
# Name: temp_f, dtype: float64

# %% [markdown]
# Show statistics for all columns in the bigfoot file.

# %%
bigfoot_valid.describe()
# Out:
#           latitude    longitude        month          day         year  \
# count  3658.000000  3658.000000  3658.000000  3658.000000  3658.000000
# mean     39.264197   -97.460664     7.258338    14.188901  1997.508748
# std       5.702536    16.730211     3.074629     8.633618    14.009316
# min      25.141000  -167.131000     1.000000     1.000000  1921.000000
# 25%      35.233020  -117.403875     5.000000     7.000000  1988.000000
# 50%      39.208640   -91.596765     8.000000    15.000000  2002.000000
# 75%      43.689788   -83.119475    10.000000    20.000000  2007.000000
# max      64.891390   -68.840500    12.000000    31.000000  2017.000000
#
#             temp_f    dew_point     humidity  cloud_cover   moon_phase  \
# count  3645.000000  3647.000000  3647.000000  3632.000000  3647.000000
# mean     59.686560    47.168618     0.686704     0.410878     0.499175
# std      15.822718    15.772096     0.143975     0.297926     0.287548
# ...

# %% [markdown]
# Find mean of only the temp_f column.

# %%
bigfoot_valid['temp_f'].mean()
# Out:
# 59.6865596707819

# %% [markdown]
# Find mean of all columns. numeric_only=True removes the categorical columns from the calculation.

# %%
bigfoot_valid.mean(numeric_only=True)
# Out:
# latitude              39.264197
# longitude            -97.460664
# month                  7.258338
# day                   14.188901
# year                1997.508748
# temp_f                59.686560
# dew_point             47.168618
# humidity               0.686704
# cloud_cover            0.410878
# moon_phase             0.499175
# precip_intensity       0.004107
# visibility             8.645849
# wind_speed             5.239781
# observed_length     1891.772665
# temp_c                15.381422
# dtype: float64

# %% [markdown]
# Find min of the temp_f column.

# %%
bigfoot_valid['temp_f'].min()
# Out:
# -7.96

# %% [markdown]
# Find max of the temp_f column.

# %%
bigfoot_valid['temp_f'].max()
# Out:
# 94.69

# %% [markdown]
# Find standard deviation of the temp_f column.

# %%
bigfoot_valid['temp_f'].std()
# Out:
# 15.822717660283413

# %% [markdown]
# Find the most common value in the state column.

# %%
bigfoot_valid['state'].mode()
# Out:
# 0    Washington
# Name: state, dtype: object

# %% [markdown]
# How many times did each state appear?

# %%
bigfoot_valid['state'].value_counts()
# Out:
# state
# Washington        483
# Florida           264
# California        257
# Ohio              243
# Illinois          195
# Texas             193
# Oregon            173
# Michigan          150
# Missouri          115
# Georgia           109
# Colorado          101
# Kentucky           97
# West Virginia      92
# Alabama            83
# Arkansas           82
# Oklahoma           74
# North Carolina     69
# Wisconsin          67
# Virginia           67
# Arizona            62
# Tennessee          57
# Idaho              49
# New York           46
# Pennsylvania       43
# Utah               41
# New Jersey         39
# Iowa               39
# Montana            39
# Indiana            39
# Minnesota          38
# Kansas             37
# Louisiana          32
# New Mexico         26
# South Carolina     25
# Massachusetts      20
# Mississippi        20
# Wyoming            14
# Nebraska           13
# Alaska             11
# Maryland           10
# Nevada              7
# ...

# %% [markdown]
# How many missing values are there in the temp_f column?

# %%
bigfoot_valid['temp_f'].isna().sum()
# Out:
# 13

# %% [markdown]
# How many missing values are there in each column of the entire dataframe?

# %%
bigfoot_valid.isna().sum()
# Out:
# state                  0
# county                 0
# latitude               0
# longitude              0
# month                  0
# day                    0
# year                   0
# classification         0
# temp_f                13
# dew_point             11
# humidity              11
# cloud_cover           26
# moon_phase            11
# precip_intensity      91
# summary               11
# visibility            11
# wind_speed            11
# observed              29
# location_details     561
# county_state           0
# observed_length       29
# season                 0
# temp_category          0
# condition_quality      0
# temp_c                13
# dtype: int64

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#3CB371; font-style:bold">
# Checkpoint</p>
#
# * How many times did each season appear in the dataframe?

# %%
bigfoot_valid['season'].value_counts()
# Out:
# season
# Summer    1280
# Fall      1054
# Spring     793
# Winter     531
# Name: count, dtype: int64

# %% [markdown]
# What is the correlation between each of the numerical columns? Note that values on the main diagonal should be ignored (the 1.000000 values) since it's measuring the correlation of a variable with itself.

# %%
bigfoot_valid.corr(numeric_only=True)
# Out:
#                   latitude  longitude     month       day      year    temp_f  \
# latitude          1.000000  -0.515797  0.022438 -0.013938 -0.027803 -0.341239
# longitude        -0.515797   1.000000 -0.024591  0.005908  0.074616  0.086687
# month             0.022438  -0.024591  1.000000 -0.013912 -0.076567  0.111254
# day              -0.013938   0.005908 -0.013912  1.000000  0.122429 -0.039903
# year             -0.027803   0.074616 -0.076567  0.122429  1.000000 -0.091341
# temp_f           -0.341239   0.086687  0.111254 -0.039903 -0.091341  1.000000
# dew_point        -0.316117   0.196233  0.122126 -0.044757 -0.090624  0.874381
# humidity          0.014959   0.217626  0.028113 -0.000007  0.012995 -0.128432
# cloud_cover       0.135349   0.025661 -0.059603 -0.033890 -0.246140 -0.253859
# moon_phase        0.016824  -0.027011 -0.006418 -0.002426  0.007319 -0.028938
# precip_intensity -0.062538   0.054290  0.031566 -0.017342  0.003316  0.034132
# ...

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Filters for Selecting Rows</h1>

# %% [markdown]
# Create a filter containing only the rows in which the temp_f was above 80. Put the results of this filter in a new dataframe called warm_temp.

# %%
warm_temp = bigfoot_valid[bigfoot_valid['temp_f'] > 80] #inside brackets are condition
warm_temp.head()
# Out:
#            state            county  latitude  longitude  month  day  year  \
# 19      Missouri  Gasconade County  38.44100  -91.62840      6   30  1954
# 22    California     Tulare County  36.10222 -118.84890      8    1  1955
# 29       Georgia       Bibb County  32.86288  -83.55708      7   15  1957
# 39      Missouri   Pemiscot County  36.00565  -89.67815      8   15  1960
# 46  Pennsylvania      Adams County  39.76366  -77.27178      7    1  1961
#
#    classification  temp_f  dew_point  humidity  cloud_cover  moon_phase  \
# 19        Class B   82.38      66.58      0.66         0.48        0.01
# 22        Class A   83.03      51.69      0.37         0.25        0.43
# 29        Class A   82.86      69.59      0.67         0.47        0.61
# 39        Class A   81.57      69.26      0.71         0.22        0.79
# 46        Class A   80.06      67.29      0.66         0.30        0.61
#
#     precip_intensity                                   summary  visibility  \
# ...

# %% [markdown]
# Next, we create some filters based on multiple criteria. Note the use of "|" for the "or" operator and "&" for the "and" operator. <b>Note the parentheses around each condition. These are annoying but mandatory.</b> You can create any combination of "and" and "or" statements using the notation below.

# %%
desert = bigfoot_valid[(bigfoot_valid['state'] == 'Arizona') | (bigfoot_valid['state'] == 'New Mexico')]
# arizona or new mexico
# when doing conditions in pandas, | is or, & is and
# put paranthases around things

# %%
desert.head()
# Out:
#        state           county  latitude  longitude  month  day  year  \
# 180  Arizona   Cochise County  31.63000  -110.1770      1    1  1972
# 238  Arizona  Coconino County  35.24100  -111.8634     12   20  1973
# 508  Arizona    Graham County  32.42445  -109.5601      6   15  1979
# 641  Arizona   Yavapai County  34.55154  -112.5421      8   15  1981
# 650  Arizona      Gila County  33.82500  -110.9250     10   15  1981
#
#     classification  temp_f  dew_point  humidity  cloud_cover  moon_phase  \
# 180        Class B   48.02      37.53      0.64         0.43        0.53
# 238        Class A   31.04      12.52      0.51         0.09        0.88
# 508        Class B   84.21      43.12      0.25         0.29        0.69
# 641        Class A   71.64      55.36      0.61         0.30        0.51
# 650        Class B   51.77      35.12      0.49         0.36        0.58
#
#      precip_intensity                                            summary  \
# ...

# %%
desert['state'].value_counts() #what states are in desert?
# Out:
# state
# Arizona       62
# New Mexico    26
# Name: count, dtype: int64

# %%
jan_wash = bigfoot_valid[(bigfoot_valid['month'] == 1) & (bigfoot_valid['state'] == 'Washington')]

# %%
jan_wash.head()
# Out:
#            state            county  latitude  longitude  month  day  year  \
# 323   Washington   Okanogan County  48.36361  -120.1211      1   30  1976
# 547   Washington  Snohomish County  48.11556  -122.0958      1   11  1980
# 663   Washington  Jefferson County  47.66530  -122.9714      1   23  1982
# 750   Washington      Clark County  45.78110  -122.5322      1   15  1984
# 1033  Washington     Pierce County  46.76600  -122.1652      1    1  1992
#
#      classification  temp_f  dew_point  humidity  cloud_cover  moon_phase  \
# 323         Class A  35.350      33.06      0.89         0.75        0.98
# 547         Class A  36.580      29.45      0.76         0.98        0.79
# 663         Class B  47.135      45.78      0.88         0.97        0.95
# 750         Class A  31.980      16.76      0.51         0.02        0.40
# 1033        Class A  41.890      36.50      0.89         0.90        0.90
#
# ...

# %% [markdown]
# Here we mix "and" and "or" conditions. Note that "and" has a higher precedence than "or", as in all programming languages. We use nested parentheses in this example to ensure that it's filtering for NJ sightings in one of the three summer months.

# %%
summer_nj_sightings = bigfoot_valid[(bigfoot_valid['state'] == 'New Jersey') & ((bigfoot_valid['month'] == 6) | (bigfoot_valid['month'] == 7) | (bigfoot_valid['month'] == 8))]

# %%
summer_nj_sightings.head()
# Out:
#            state          county  latitude  longitude  month  day  year  \
# 373   New Jersey   Mercer County  40.18478  -74.72261      6    3  1977
# 381   New Jersey   Sussex County  41.13498  -74.80315      7    9  1977
# 521   New Jersey  Passaic County  41.06945  -74.15562      8   15  1979
# 963   New Jersey   Sussex County  41.29596  -74.68832      6   15  1990
# 1007  New Jersey   Sussex County  41.30566  -74.68540      7    1  1991
#
#      classification  temp_f  dew_point  humidity  cloud_cover  moon_phase  \
# 373         Class A  59.370      43.86      0.51         0.43        0.57
# 381         Class A  74.585      66.13      0.73         0.48        0.79
# 521         Class B  62.880      50.21      0.60         0.47        0.77
# 963         Class B  67.360      60.09      0.81         0.68        0.73
# 1007        Class B  72.460      51.37      0.54         0.41        0.64
#
#       precip_intensity                                            summary  \
# ...

# %% [markdown]
# You'll notice that the row indices are not contiguous. That's because we grabbed rows from different parts of the DataFrame due to the filtering. If you want the row indices to be contiguous, use 'reset_index()' at the end of the command.

# %%
summer_nj_sightings = bigfoot_valid[(bigfoot_valid['state'] == 'New Jersey') & ((bigfoot_valid['month'] == 6) | (bigfoot_valid['month'] == 7) | (bigfoot_valid['month'] == 8))].reset_index()
summer_nj_sightings.head()
# reset says idgaf where valued rows where, lets renumber them from 0
# Out:
#    index       state          county  latitude  longitude  month  day  year  \
# 0    373  New Jersey   Mercer County  40.18478  -74.72261      6    3  1977
# 1    381  New Jersey   Sussex County  41.13498  -74.80315      7    9  1977
# 2    521  New Jersey  Passaic County  41.06945  -74.15562      8   15  1979
# 3    963  New Jersey   Sussex County  41.29596  -74.68832      6   15  1990
# 4   1007  New Jersey   Sussex County  41.30566  -74.68540      7    1  1991
#
#   classification  temp_f  dew_point  humidity  cloud_cover  moon_phase  \
# 0        Class A  59.370      43.86      0.51         0.43        0.57
# 1        Class A  74.585      66.13      0.73         0.48        0.79
# 2        Class B  62.880      50.21      0.60         0.47        0.77
# 3        Class B  67.360      60.09      0.81         0.68        0.73
# 4        Class B  72.460      51.37      0.54         0.41        0.64
#
#    precip_intensity                                            summary  \
# ...

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#3CB371; font-style:bold">
# Checkpoint</p>
#
# * Create a filter on the dataframe to capture only the sightings in NJ with a visibility greater than 2 miles. Call the new dataframe "nj_good_vis".

# %%
nj_good_vis = bigfoot_valid[(bigfoot_valid['visibility'] > 2) & (bigfoot_valid['state'] == 'New Jersey')].reset_index()
nj_good_vis['county'].value_counts()
# Out:
# county
# Sussex County        9
# Burlington County    6
# Morris County        5
# Ocean County         4
# Passaic County       3
# Warren County        3
# Salem County         2
# Mercer County        1
# Somerset County      1
# Middlesex County     1
# Essex County         1
# Hunterdon County     1
# Cape May County      1
# Name: count, dtype: int64

# %%
nj_good_vis.shape
# Out:
# (38, 26)

# %% [markdown]
# Sometimes columns containing text aren't categorical. For example, this dataset contains an "observed" column with a text description of the sighting, where each description is unique. We can't do a simple filter on this because the string we might look for is embedded somewhere within the text. The next example shows how we could extract the rows in which the word "scary" is in the "observed" column. The case=False part makes sure it captures the word regardless of capitalization.

# %%
scary = bigfoot_valid[bigfoot_valid['observed'].str.contains('scary', case=False) == True].reset_index()
scary.head()
# Out:
#    index       state               county  latitude  longitude  month  day  \
# 0     78  California        Sutter County  39.20500 -121.58000      7    1
# 1     93    Michigan  Presque Isle County  45.40985  -83.85985      5   17
# 2     95  Washington        Pierce County  46.95100 -122.29850      7   15
# 3    240  California      Monterey County  35.55650 -121.29190      4   15
# 4    247     Georgia       Douglas County  34.00000  -85.00000      6   15
#
#    year classification  temp_f  dew_point  humidity  cloud_cover  moon_phase  \
# 0  1965        Class A  76.330      52.78      0.57         0.04        0.10
# 1  1967        Class A  48.380      26.88      0.47         0.62        0.27
# 2  1967        Class B  65.930      45.79      0.52         0.01        0.29
# 3  1974        Class A  54.805      45.77      0.73         0.27        0.78
# 4  1974        Class A  74.330      63.12      0.74         0.65        0.83
#
# ...

# %% [markdown]
# Reminder: If you want to see the entire dataframe, including full strings, use the following:
#
# <b>pd.options.display.max_columns = None<b>
#
# We will not run this command here because some descriptions are really long and it makes the dataframe unwieldy.
#
# If you run this command and have second thoughts, you can restore it to the default via:
#
# <b>pd.reset_option("display.max_columns")</b>
#
# You will have to restart the kernel and run all cells to prompt the change.

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#3CB371; font-style:bold">
# Checkpoint</p>
#
# * Create a filter on the dataframe to capture only the sightings where the "observed" field mentions either "woods" or "giant".

# %%
woods_giant = bigfoot_valid[(bigfoot_valid['observed'].str.contains('woods', case=False) == True) | (bigfoot_valid['observed'].str.contains('giant', case=False) == True)].reset_index()
woods_giant.head()
# Out:
#    index        state            county  latitude  longitude  month  day  \
# 0      1    Louisiana  Avoyelles Parish  31.08774  -91.84467     10   14
# 1      7     Michigan      Alger County  46.35503  -86.97000      7    1
# 2      8   California   Siskiyou County  41.82417 -122.99580      8    1
# 3      9      Florida     Putnam County  29.77295  -81.68295      7    1
# 4     13  Mississippi     Attala County  33.10925  -89.59135      1    1
#
#    year classification  temp_f  dew_point  humidity  cloud_cover  moon_phase  \
# 0  1925        Class B     NaN        NaN       NaN          NaN         NaN
# 1  1944        Class B   64.57      54.50      0.72         0.37        0.34
# 2  1944        Class A     NaN        NaN       NaN          NaN         NaN
# 3  1947        Class A   77.50      72.16      0.84         0.93        0.44
# 4  1950        Class A   63.54      54.84      0.81         0.95        0.41
#
# ...

# %%
woods_giant.shape[0]
# Out:
# 1408

# %% [markdown]
# * How many sightings are in the dataframe just created?

# %% [markdown]
# 1408

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Group By and Aggregate</h1>

# %% [markdown]
# We can use groupby to break results out by a certain column or columns, much like pivot tables in Excel.

# %% [markdown]
# What is the average sighting temperature, grouped by season?

# %%
bigfoot_valid.groupby('season')['temp_f'].mean()
# Out:
# season
# Fall      51.441744
# Spring    63.491926
# Summer    71.129929
# Winter    42.815890
# Name: temp_f, dtype: float64

# %% [markdown]
# Sometimes groupbys are not printed out in an aesthetically pleasing way. You can convert the output to a dataframe with the pd.DataFrame command. We won't worry about this too much for the rest of the tutorial.

# %%
pd.DataFrame(bigfoot_valid.groupby('season')['temp_f'].mean())
# Out:
#            temp_f
# season
# Fall    51.441744
# Spring  63.491926
# Summer  71.129929
# Winter  42.815890

# %% [markdown]
# For every numerical column, what is the average value, grouped by season?

# %%
bigfoot_valid.groupby('season').mean(numeric_only=True)
# Out:
#          latitude  longitude      month        day         year     temp_f  \
# season
# Fall    38.917595 -96.026856  10.727704  14.458254  1997.664137  51.441744
# Spring  39.423211 -97.377762   5.160151  14.828499  1997.963430  63.491926
# Summer  39.859652 -99.758614   7.939063  13.403906  1995.292187  71.129929
# Winter  38.279336 -94.891173   1.864407  14.591337  2001.864407  42.815890
#
#         dew_point  humidity  cloud_cover  moon_phase  precip_intensity  \
# season
# Fall    40.666112  0.717395     0.442578    0.499534          0.004755
# Spring  49.897134  0.662803     0.413143    0.506540          0.004626
# Summer  57.118822  0.663566     0.347269    0.492506          0.003755
# Winter  32.098887  0.717075     0.497524    0.503472          0.002919
#
#         visibility  wind_speed  observed_length     temp_c
# season
# Fall      8.457880    5.507823      1859.078170  10.800969
# Spring    8.905985    5.556843      1861.590793  17.495514
# ...

# %% [markdown]
# What is the maximum sighting temperature, grouped by season?

# %%
pd.DataFrame(bigfoot_valid.groupby('season')['temp_f'].max())
# Out:
#         temp_f
# season
# Fall     82.82
# Spring   90.55
# Summer   94.69
# Winter   76.47

# %% [markdown]
# How many sightings are there, grouped by season?

# %%
pd.DataFrame(bigfoot_valid.groupby('season')['temp_f'].count())
# Out:
#         temp_f
# season
# Fall      1052
# Spring     792
# Summer    1273
# Winter     528

# %% [markdown]
# You can also use the sum function. It doesn't make much sense to use here, but this example calculates the sum of all temp_f values by season.

# %%
bigfoot_valid.groupby('season')['temp_f'].sum()
# Out:
# season
# Fall      54116.715
# Spring    50285.605
# Summer    90548.400
# Winter    22606.790
# Name: temp_f, dtype: float64

# %% [markdown]
# We can break results down by several columns if desired.
#
# How many sightings are there for each season and classification? Unstack formats the table in a nicer format.

# %%
class_by_season_counts = bigfoot_valid.groupby(['classification','season'])['temp_f'].mean().unstack()
class_by_season_counts
# Out:
# season               Fall     Spring     Summer     Winter
# classification
# Class A         51.111969  63.911517  71.325352  43.203897
# Class B         51.870374  63.044409  70.893516  42.309100
# Class C         38.330000  68.900000  74.775625  50.372500

# %% [markdown]
# If we want more than one metric calculated for the groupby, we can use the 'agg' function and feed it the list of desired metrics.

# %%
class_by_season_info = bigfoot_valid.groupby(['classification','season'])['temp_f'].agg(["max", "min"])
class_by_season_info
# Out:
#                          max    min
# classification season
# Class A        Fall    82.82   6.08
#                Spring  88.38  24.50
#                Summer  94.69  44.18
#                Winter  76.47  -1.92
# Class B        Fall    82.22  -7.96
#                Spring  90.55  23.02
#                Summer  90.29  46.73
#                Winter  75.40   3.22
# Class C        Fall    59.35  16.56
#                Spring  68.90  68.90
#                Summer  86.86  65.64
#                Winter  65.04  41.10

# %% [markdown]
# For numerical values, we can use the cut function to create bins for the values. If we want equally spaced bins, we can specify the number of bins:

# %%
bigfoot_valid['temp_bin'] = pd.cut(x=bigfoot_valid['temp_f'], bins=3, right=True)
bigfoot_valid[['temp_f','temp_bin']].head(10)
# Out:
#    temp_f          temp_bin
# 0     NaN               NaN
# 1     NaN               NaN
# 2   74.49   (60.473, 94.69]
# 3     NaN               NaN
# 4     NaN               NaN
# 5   57.97  (26.257, 60.473]
# 6   63.00   (60.473, 94.69]
# 7   64.57   (60.473, 94.69]
# 8     NaN               NaN
# 9   77.50   (60.473, 94.69]

# %% [markdown]
# Unfortunately this often uses fractional values that don't look nice in an output table. Let's try specifying the bin boundaries instead:

# %%
bigfoot_valid['temp_bin'] = pd.cut(x=bigfoot_valid['temp_f'], bins=[-10, 20, 50, 80, 110],
                    labels=['-10 to 20', '20 to 50', '50 to 80', '80 to 110',])
bigfoot_valid[['temp_f','temp_bin']].head(10)
# Out:
#    temp_f  temp_bin
# 0     NaN       NaN
# 1     NaN       NaN
# 2   74.49  50 to 80
# 3     NaN       NaN
# 4     NaN       NaN
# 5   57.97  50 to 80
# 6   63.00  50 to 80
# 7   64.57  50 to 80
# 8     NaN       NaN
# 9   77.50  50 to 80

# %% [markdown]
# There's also a function called qcut that can cut the data based on quantiles (the distribution of the data) rather than just cutting into constant sized bins based on the min and max values.

# %%
bigfoot_valid['temp_quantiles'] = pd.qcut(bigfoot_valid['temp_f'], q=5, labels=['0-20%',
                                '20-40%',
                                '40-60%', 
                                '60-80%',
                                '80-100%'])
# Only need to see the two relevant columns to determine if it worked correctly.
bigfoot_valid[['temp_f','temp_quantiles']].head(10)
# Out:
#    temp_f temp_quantiles
# 0     NaN            NaN
# 1     NaN            NaN
# 2   74.49        80-100%
# 3     NaN            NaN
# 4     NaN            NaN
# 5   57.97         40-60%
# 6   63.00         40-60%
# 7   64.57         40-60%
# 8     NaN            NaN
# 9   77.50        80-100%

# %% [markdown]
# How many times were temperatures in each bin observed by season?

# %%
class_by_temp_bin_count = bigfoot_valid.groupby(['temp_bin', 'season'])['temp_bin'].count().unstack()
class_by_temp_bin_count
# Out:
# season     Fall  Spring  Summer  Winter
# temp_bin
# -10 to 20    17       0       0      41
# 20 to 50    472     103      12     341
# 50 to 80    559     619    1035     146
# 80 to 110     4      70     226       0

# %% [markdown]
# You can combine filters and groupbys. One approach is to create a filter and save it to a new dataframe, then use groupby on the new dataframe. Alternatively, if you want a quick calculation, you could do it all in one line.
#
# Let's do the same calculation as above, but only for NJ observations.

# %%
class_by_temp_bin_nj_count = bigfoot_valid[bigfoot_valid['state']=='New Jersey'].groupby(['temp_bin', 'season'])['temp_bin'].count().unstack()
class_by_temp_bin_nj_count
# Out:
# season     Fall  Spring  Summer  Winter
# temp_bin
# -10 to 20     0       0       0       0
# 20 to 50     13       0       0       8
# 50 to 80      5       6       5       1
# 80 to 110     0       0       1       0

# %% [markdown]
# You can also combine groupbys with the describe function covered earlier.

# %%
bigfoot_valid.groupby('classification')['temp_f'].describe()
# Out:
#                  count       mean        std    min     25%     50%       75%  \
# classification
# Class A         1831.0  59.685950  16.094593  -1.92  49.105  61.880  72.18500
# Class B         1798.0  59.671274  15.523173  -7.96  49.045  61.725  71.70000
# Class C           16.0  61.474063  18.614708  16.56  49.710  66.730  72.92875
#
#                   max
# classification
# Class A         94.69
# Class B         90.55
# Class C         86.86

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#3CB371; font-style:bold">
# Checkpoint</p>
#
# * Create bins to assign a hemisphere (Northern vs. Southern) to each observation. Assign the value to a column called 'hemisphere'. How many observations were there in each hemisphere?

# %% [markdown]
# * Create a bins to assign a decade to each observation (there's a math trick that will help with this) and call the new column 'decade'. What was the maximum wind speed observed in the dataset, grouped by hemisphere and decade?

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Pivot Tables</h1>

# %% [markdown]
# Pandas has a similar functionality to groupbys called pivot tables, which are akin to their usage in Excel. The main difference is how the output is formatted by default. There's a longer tutorial of pivot tables at https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html. Generally speaking, there's not a strong reason in this class to use one over the other.
#
# The following two examples yield the identical result.

# %%
bigfoot_valid.groupby(['classification','season'])['temp_f'].mean().unstack()
bigfoot_valid.pivot_table('temp_f', index='classification', columns='season')
# Out:
# season               Fall     Spring     Summer     Winter
# classification
# Class A         51.111969  63.911517  71.325352  43.203897
# Class B         51.870374  63.044409  70.893516  42.309100
# Class C         38.330000  68.900000  74.775625  50.372500

# %% [markdown]
# You can have multilevel pivot tables, just as you could for groupbys. Here is an example using groupby followed by the same using a pivot table. You will see NaN where there was no data. This seems logical here, as you wouldn't expect temp_f values between -10 and 20 in the spring and summer.

# %%
#bigfoot_valid.groupby(['classification','temp_bin','season'])['temp_f'].mean().unstack()
bigfoot_valid.pivot_table('temp_f', ['classification','temp_bin'], 'season')
# Out:
# season                         Fall     Spring     Summer     Winter
# classification temp_bin
# Class A        -10 to 20  14.227222        NaN        NaN  12.062500
#                20 to 50   40.960949  44.322065  46.401667  38.578179
#                50 to 80   61.356173  64.267707  68.711207  61.361835
#                80 to 110  82.375000  82.703690  83.200533        NaN
# Class B        -10 to 20  10.625714        NaN        NaN  13.377368
#                20 to 50   41.094197  44.640439  47.885833  38.776356
#                50 to 80   61.048808  64.721365  68.838788  60.386000
#                80 to 110  81.260000  82.302679  82.963725        NaN
# Class C        -10 to 20  16.560000        NaN        NaN        NaN
#                20 to 50   39.080000        NaN        NaN  42.352500
#                50 to 80   59.350000  68.900000  71.644167  58.392500
#                80 to 110        NaN        NaN  84.170000        NaN

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Exporting Dataframes to File</h1>

# %% [markdown]
# Sometimes you'll want to create all of your visuals in Python. Other times, you may want to do some pre-processing in Python and finish things up in Excel or Tableau. In the latter case, it's helpful to export the dataframe to a csv or Excel file and then load that into Excel/Tableau. This is very easy to do.
#
# You can only export a single dataframe to a single csv file. You can export multiple dataframes to an Excel file, but it's a little tricky. I'd recommend saving to separate files if there are only a few dataframes that you'll need to export.

# %%
bigfoot_valid.to_csv('output_file_name.csv')

# %%
bigfoot_valid.to_excel('another_output_file_name.xlsx')

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Data Visualization</h1>

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot') #use builtin style

# %% [markdown]
# Make a histogram of the temperatures found in the temp_f column. Make the output 15 inches x 10 inches. Jupyter will scale it but you could save the histogram to a file and that would be the size of the image.

# %%
bigfoot_valid.hist(column='temp_f', figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'temp_f'}>]], dtype=object)

# %%
plt.style.use('bmh')
bigfoot_valid.hist(column='temp_f', figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'temp_f'}>]], dtype=object)

# %%
plt.style.use('dark_background')
bigfoot_valid.hist(column='temp_f', figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'temp_f'}>]], dtype=object)

# %%
plt.style.use('fivethirtyeight')
bigfoot_valid.hist(column='temp_f', figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'temp_f'}>]], dtype=object)

# %%
plt.style.use('ggplot')

# %% [markdown]
# Let's stick with the ggplot style.

# %% [markdown]
# Plot the twenty-five most common state in which Bigfoot observations occurred as a bar graph. Sort it from most common to least common.

# %%
bigfoot_valid['state'].value_counts(sort=True)[:25].plot.bar(figsize=(15,10))
# Out:
# <Axes: xlabel='state'>

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#3CB371; font-style:bold">
# Checkpoint</p>
#
# * Plot the 15 most common years in which Bigfoot sightings were recorded as a bar graph. Sort it from highest to lowest.

# %%
plt.style.use('seaborn-v0_8')
bigfoot_valid['year'].value_counts(sort=True)[:15].plot.bar(figsize=(15,10))
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# Let's examine the length of the average observed text grouped by year.

# %%
seasonal_average_by_year = bigfoot_valid[['year','observed_length']].groupby('year', as_index=False).mean()
seasonal_average_by_year[:10]
# Out:
#    year  observed_length
# 0  1921              NaN
# 1  1925           1138.0
# 2  1930           1006.0
# 3  1937              NaN
# 4  1938           2509.0
# 5  1941           1423.0
# 6  1942            436.0
# 7  1944            888.0
# 8  1947           2546.0
# 9  1948            382.0

# %% [markdown]
# Plot the data from the table immediately above. It looks like the length of the encountered descriptions are getting shorter over time. We also have some missing years from the 1930s.

# %%
seasonal_average_by_year.plot(x='year', y='observed_length', figsize=(15,10), grid=True)
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#3CB371; font-style:bold">
# Checkpoint</p>
#
# * Plot the average temp_f by year as a line graph.

# %%
plt.style.use('seaborn-v0_8-whitegrid')
temp_by_year = bigfoot_valid[['year','temp_f']].groupby('year', as_index=False).mean()
temp_by_year[:10]
temp_by_year.plot(x='year', y='temp_f', figsize=(15,10), grid=True)
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0"> Some Additional Advice </h1>

# %% [markdown]
# 1. If you're encountering a strange error, try rerunning all cells. There's a good chance that along the way you messed up the DataFrame and we need to load and rerun everything from scratch. Remember that Jupyter Notebooks retain all variables in memory as you're running the cells.

# %% [markdown]
# 2. If you want to use groupby results in a graph, you'll have to use reset_index first. Here's an example...

# %%
temp_by_classification = pd.DataFrame(bigfoot_valid.groupby('classification')['temp_f'].count())
temp_by_classification
# Out:
#                 temp_f
# classification
# Class A           1831
# Class B           1798
# Class C             16

# %% [markdown]
# Notice how the temp_f string is placed a bit higher than the classification column. That's because it's not considered a column. To fix this, follow the example below. You will then see it listed when you do "bigfoot_valid.columns" and can use it to make a bar chart or other graphic.

# %%
temp_by_classification = temp_by_classification.reset_index()

# %% [markdown]
# 3. If you need to run any of this from home, you can either install install Anaconda Navigator at home and set up your files just like you do in school, or you can use Google Colaboratory. Here's a screenshot of the steps I gave students in a prior semester:

# %% [markdown]
# <div>
# <img src="attachment:6447702e-0f4e-4244-9215-78a7f6c0253c.png" width="700">
# </div>

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0"> More Plot Types </h1>
#
# There are several plot types built-in to pandas, most of them statistical plots by nature:
#
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie
#
# You can also just call df.plot(kind='hist') or replace that kind argument with any of the key terms shown in the list above (e.g. 'box','barh', etc..)
# ___

# %% [markdown]
# ## Read in Some Fictitious Data
#
# We have some fake data stored in df1.csv and df2.csv which will be used for the examples that follow.

# %%
df1 = pd.read_csv('./data/df1.csv',index_col=0)
df2 = pd.read_csv('./data/df2.csv')

# %% [markdown]
# Let's start going through them!
#
# ## Area

# %%
plt.style.use('seaborn-v0_8-pastel')
df2.plot.area(alpha=0.5,figsize=(15,10))
# Out:
# <Axes: >

# %% [markdown]
# ## Barplots

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
plt.style.use('seaborn-v0_8-pastel')
df2.plot.bar(figsize=(15,10))
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-v0_8-pastel')
df2.plot.bar(stacked=True,figsize=(15,10))
# Out:
# <Axes: >

# %% [markdown]
# ## Histograms

# %%
plt.style.use('seaborn-v0_8-pastel')
df1['A'].plot.hist(bins=50,figsize=(15,10))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Line Plots

# %%
plt.style.use('seaborn-v0_8-pastel')
df1.plot.line(y='B',figsize=(15,10),lw=1, use_index=True)
# Here we just used the index that counts up by one as our x. If you wanted to use the x coordinate from a column, 
#just put that before the y='B'.
# For example: df1.plot.line(x='A', y='B',figsize=(12,3),lw=1)
# Out:
# <Axes: xlabel='Index'>

# %% [markdown]
# ## Scatter Plots

# %%
plt.style.use('seaborn-v0_8-pastel')
df1.plot.scatter(x='A',y='B',figsize=(15,10))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# You can use c to color based off another column value
# Use cmap to indicate colormap to use.
# For all the colormaps, check out: http://matplotlib.org/users/colormaps.html

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm',figsize=(15,10))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# Or use s to indicate size based off another column. s parameter needs to be an array, not just the name of a column:

# %%
plt.style.use('seaborn-v0_8-pastel')
df1.plot.scatter(x='A',y='B',s=df1['C']*200,figsize=(15,10))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# ## BoxPlots

# %%
plt.style.use('seaborn-v0_8-pastel')

df2.plot.box(figsize=(15,10)) # Can also pass a by= argument for groupby
# Out:
# <Axes: >

# %% [markdown]
# ## Hexagonal Bin Plot
#
# Useful for Bivariate Data, alternative to scatterplot:

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges',figsize=(15,10))
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ____

# %% [markdown]
# ## Kernel Density Estimation plot (KDE)

# %%
df2['a'].plot.kde(figsize=(15,10))
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.density(figsize=(15,10))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# That's it! Hopefully you can see why this method of plotting will be a lot easier to use than full-on matplotlib, it balances ease of use with control over the figure. A lot of the plot calls also accept additional arguments of their parent matplotlib plt. call.
#
# In the next section, we will learn about seaborn, which is a statistical visualization library designed to work with pandas dataframes well.
